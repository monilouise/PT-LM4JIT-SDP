# %% [markdown]
# # CodeFlowLM - Notebook with results run on Google Colab/UFPE Cluster/Personal laptop

# %% [markdown]
# ## Code preparation

# %%
# !git clone https://github.com/monilouise/PEFT4CC.git

# %%
# !rm -r codeflowlm/

# %%
# !git clone https://github.com/monilouise/codeflowlm.git
# Out:
# Cloning into 'codeflowlm'...

# %%
# %cd codeflowlm
# !git checkout tags/v1.0.0

# %%
import sys
sys.path.append('codeflowlm')

# %%
path = 'data'
full_features_train_file = f"{path}/ord_cross_features_train.pkl"
full_features_valid_file = f"{path}/ord_cross_features_valid.pkl"
full_features_test_file = f"{path}/ord_cross_features_test.pkl"
full_changes_train_file = f"{path}/ord_cross_changes_train_lst.pkl"
full_changed_valid_file = f"{path}/ord_cross_changes_valid_lst.pkl"
full_changes_test_file = f"{path}/ord_cross_changes_test_lst.pkl"
commit_guru_path = f"{data}/commit_guru"
model_root = "." #path where the models will be saved
batch_classifier_dir = '.' #e.g: PEFT4CC

# %% [markdown]
# ## Libraries Installation

# %%
# !pip install dill

# %%
# !pip install transformers==4.51.3 #for UniXCoder!!!

# %%
# !pip install git+https://github.com/thunlp/OpenDelta.git

# %%
# !pip install river

# %% [markdown]
# ## Training
#
# OBS.: Training logs are ommited for better clarity.

# %%
import codeflowlm.train

# %% [markdown]
# ### ant-ivy

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='ant-ivy',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:c19ef756-ec0d-4def-94d9-26aaeaad4432.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='ant-ivy', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:73b1758c-30bb-4193-8e19-0943cc758f88.png)

# %% [markdown]
# #### BORB (LR)
#
# ![best-ant-ivy_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-bcel

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-bcel',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:f807f11a-3425-40a8-9bb6-3b0da552a91e.png)

# %% [markdown]
# #### UniXCoder
#
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (LR)
#
# ![best_commons-bcel_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-beanutils

# %% [markdown]
# #### Codet5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-beanutils',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:89cc119c-4c44-4446-8bc7-f58d234b7cdd.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-beanutils', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:7755ba01-a4ca-4359-afc7-9b186a755d1f.png)

# %% [markdown]
# #### BORB (MLP)
#
# ![best-commons-beanutils-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-codec

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-codec',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# (First graph version)
#
# ![image.png](attachment:098a7e16-add5-494b-95c3-0d1c51d1ff6d.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-codec', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:4faafb95-0274-4136-8b83-57e25742d8ab.png)

# %% [markdown]
# #### BORB (LR)
#
# ![best-commons-codec-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-collections

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-collections',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:72c7abd0-8bb7-46dc-941c-c40ff64dd28e.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-collections', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (IRF)
#
# ![best-commons-collections-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-compress

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-compress',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:b2d64721-ad49-45d1-8620-fd8eb2fa429d.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-compress', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:795bfd9c-a8de-4a21-aa04-e20fc86723db.png)

# %% [markdown]
# #### BORB (MLP)
#
# ![best-commons-compress-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-configuration

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-configuration',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:5016b061-43fa-4b2d-9d70-5ba01a80656c.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-configuration', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:73f64d30-ab22-489c-8c74-8682be5e6894.png)

# %% [markdown]
# #### BORB (LR)
#
# ![best-commons-configuration-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-digester

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-digester',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:04eaec2b-e484-4b92-9d2a-8fc065f25074.png)

# %% [markdown]
# #### UniXCoder
#
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (MLP)
#
# ![best-commons-digester-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-jcs

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-jcs',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:326a7d7c-03c6-405c-8945-e10a9d77866e.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-jcs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:b432f99c-850e-45d6-bd73-b507d86f92ef.png)

# %% [markdown]
# #### BORB (MLP)
#
# ![best-commons-jcs-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-lang

# %% [markdown]
# #### CodeT5+

# %% [markdown]
# #Run on cluster
# codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
#                                             full_features_train_file,
#                                             full_features_valid_file,
#                                             full_features_test_file,
#                                             full_changes_train_file,
#                                             full_changed_valid_file,
#                                             full_changes_test_file,
#                                             project='commons-lang',
#                                             early_stop_metric='gmean',
#                                             adjust_th=False,
#                                             skewed_oversample=True,
#                                             adjust_th_on_test=False)

# %% [markdown]
# ![plot_commons-lang.png](data:image/png;base64,...)

# %% [markdown]
# #### UniXCoder
#
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (LR)
#
# ![best_commons-lang_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-math

# %% [markdown]
# #### CodeT5+

# %% [markdown]
# (run on cluster)
#
# ![plot_commons-math.png](data:image/png;base64,...)

# %% [markdown]
# #### UniXCoder

# %% [markdown]
# (run on cluster)
#
# ![plot-commons-math_unixcoder.png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (MLP)
#
# ![best_commons-math_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-net

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-net',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:bb81d8c2-ff38-44d2-8d2f-4d3aecfb790b.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-net', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:6b5cf33b-33eb-44e5-8c5e-817dd93776da.png)

# %% [markdown]
# #### BORB (IRF)
#
# ![best-commons-net-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-scxml

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-scxml',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:631fdcc3-0e76-438b-8813-689a50de6507.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-scxml', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![plot (1).png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (LR)
#
# ![best_commons-scxml_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-validator

# %% [markdown]
# #### CodetT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-validator',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# ![image.png](attachment:87015b5a-61c9-4322-a61c-d0f09a7824d3.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-validator', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:dfb0fce3-770b-4898-9a95-243ba506d3e3.png)

# %% [markdown]
# #### BORB (MLP)
#
# ![best-commons-validator-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### commons-vfs

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(path, model_root, commit_guru_path,
                                            full_features_train_file,
                                            full_features_valid_file,
                                            full_features_test_file,
                                            full_changes_train_file,
                                            full_changed_valid_file,
                                            full_changes_test_file,
                                            project='commons-vfs',
                                            early_stop_metric='gmean',
                                            adjust_th=False,
                                            skewed_oversample=True,
                                            adjust_th_on_test=False)

# %% [markdown]
# (First graph version)
#
# ![image.png](attachment:b36e4573-a9d3-4daa-9921-21b37e991dc0.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-vfs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:b42fcb98-7b0a-4e32-9f96-85112c05c951.png)

# %% [markdown]
# #### BORB (NB)
#
# ![best-commons-vfs-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### giraph

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='giraph', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16)

# %% [markdown]
# ![image.png](attachment:6b37ef0a-3c01-40fb-9aff-9fb016d40bac.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='giraph', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:4a70baf6-c5e4-48f5-8781-0098f0047852.png)

# %% [markdown]
# #### BORB (LR)
#
# ![best_giraph_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### gora

# %% [markdown]
# #### CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='gora', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16)

# %% [markdown]
# ![image.png](attachment:c9fb0b19-9e07-4aee-81a7-244d1696da5e.png)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='gora', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![plot (2).png](data:image/png;base64,...)

# %% [markdown]
# #### BORB (IRF)
#
# ![best-gora-recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### opennlp

# %% [markdown]
# #### CodeT5+

# %% [markdown]
# (run on cluster)
#
# ![plot_opennlp.png](data:image/png;base64,...)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='opennlp', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:56128157-c101-46cc-a19b-403c0c4691e0.png)

# %% [markdown]
# #### BORB (LR)
#
# ![best_opennlp_recalls_gmean.png](data:image/png;base64,...)

# %% [markdown]
# ### parquet-mr

# %% [markdown]
# #### CodeT5+

# %% [markdown]
# (run on cluster)
#
# ![plot-parquet-mr.png](data:image/png;base64,...)

# %% [markdown]
# #### UniXCoder

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='parquet-mr', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            adjust_th_on_test=False, batch_size=16, pretrained_model='unixcoder')

# %% [markdown]
# ![image.png](attachment:a9b507f6-ec5f-4d42-a1c9-75e9e70e5edd.png)

# %% [markdown]
# #### BORB (NB)
#
# ![best_parquet-mr_recalls_gmean.png](data:image/png;base64,...)
